# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaidehiiii/EDA-terrorism--lgm/blob/main/Exploratory%20Data%20Analysis%20on%20Dataset%20-%20Terrorism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exploratory Data Analysis on Dataset - Terrorism**
#
# -Vaidehi Pawar
#
# LGM Internship

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin1')
print(data)
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 18865  198305240006   1983       5    24        NaN         0        NaN
# 18866  198305240007   1983       5    24        NaN         0        NaN
# 18867  198305240008   1983       5    24        NaN         0        NaN
# 18868  198305240009   1983       5    24        NaN         0        NaN
# 18869  198305240010   1983       5    24        NaN         0        NaN
#
#        country         country_txt  region  ... addnotes scite1 scite2  \
# 0           58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130              Mexico       1  ...      NaN    NaN    NaN
# 2          160         Philippines       5  ...      NaN    NaN    NaN
# 3           78              Greece       8  ...      NaN    NaN    NaN
# 4          101               Japan       4  ...      NaN    NaN    NaN
# ...        ...                 ...     ...  ...      ...    ...    ...
# 18865       45            Colombia       3  ...      NaN    NaN    NaN
# 18866       45            Colombia       3  ...      NaN    NaN    NaN
# 18867      145           Nicaragua       2  ...      NaN    NaN    NaN
# 18868      145           Nicaragua       2  ...      NaN    NaN    NaN
# 18869      603      United Kingdom       8  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0         NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 1         NaN      PGIS      0.0       1.0      1.0     1.0      NaN
# 2         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 4         NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# ...       ...       ...      ...       ...      ...     ...      ...
# 18865     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 18866     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 18867     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 18868     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 18869     NaN       NaN      NaN       NaN      NaN     NaN      NaN
#
# [18870 rows x 135 columns]
# <ipython-input-75-3cd98628f872>:6: DtypeWarning: Columns (4,31,33,62,76,79,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin1')

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
data.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 18865  198305240006   1983       5    24        NaN         0        NaN
# 18866  198305240007   1983       5    24        NaN         0        NaN
# 18867  198305240008   1983       5    24        NaN         0        NaN
# 18868  198305240009   1983       5    24        NaN         0        NaN
# 18869  198305240010   1983       5    24        NaN         0        NaN
#
#        country     country_txt  region  ... addnotes scite1 scite2  scite3  \
# 18865       45        Colombia       3  ...      NaN    NaN    NaN     NaN
# 18866       45        Colombia       3  ...      NaN    NaN    NaN     NaN
# 18867      145       Nicaragua       2  ...      NaN    NaN    NaN     NaN
# 18868      145       Nicaragua       2  ...      NaN    NaN    NaN     NaN
# 18869      603  United Kingdom       8  ...      NaN    NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 18865      PGIS      0.0       0.0      0.0     0.0      NaN
# 18866      PGIS      0.0       0.0      0.0     0.0      NaN
# 18867      PGIS      0.0       0.0      0.0     0.0      NaN
# 18868      PGIS      0.0       0.0      0.0     0.0      NaN
# 18869       NaN      NaN       NaN      NaN     NaN      NaN
#
# [5 rows x 135 columns]

# %%
data.shape
# Out:
# (18870, 135)

# %%
data.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.887000e+04  18870.000000  18870.000000  18870.000000  18870.000000
# mean   1.978580e+11   1978.517011      6.198781     15.206465      0.019131
# std    3.406406e+08      3.409654      3.448318      8.955007      0.136989
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.977042e+11   1977.000000      3.000000      8.000000      0.000000
# 50%    1.979101e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.981082e+11   1981.000000      9.000000     23.000000      0.000000
# max    1.983052e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  18870.000000  18870.000000  18123.000000  1.812300e+04  18870.000000
# mean     177.541176      5.416428     26.370738 -4.786345e+03      1.289401
# std      166.162416      3.357730     22.515713  6.402079e+05      0.952265
# min        4.000000      1.000000    -45.867889 -8.618590e+07      1.000000
# 25%       69.000000      2.000000     13.692880 -8.688120e+01      1.000000
# 50%      110.000000      5.000000     33.888523 -6.926293e+00      1.000000
# 75%      209.000000      8.000000     43.184180  9.174508e+00      1.000000
# max      605.000000     12.000000     64.837778  1.726362e+02      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  4.330000e+02          1.0  9.000000e+01           1.0
# mean   ...  3.788639e+06      20000.0  1.333696e+06           0.0
# std    ...  4.845468e+07          NaN  4.800603e+06           NaN
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  7.750000e+04           0.0
# 75%    ...  4.350000e+05      20000.0  7.750000e+05           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count      670.000000  510.000000  18869.000000  18869.000000  18869.000000
# mean         2.902985    8.225490     -3.631989     -3.589485      0.249987
# std          1.298898   28.655294      4.529369      4.575088      0.645339
# min          2.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      1.000000
# max          7.000000  215.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  18869.000000
# mean      -2.612963
# std        4.518743
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 79 columns]

# %%
data.corr()
# Out:
# <ipython-input-80-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999891 -0.078206 -0.007034 -0.060690 -0.335552
# iyear      0.999891  1.000000 -0.088343 -0.007323 -0.060776 -0.335398
# imonth    -0.078206 -0.088343  1.000000  0.014218  0.013265  0.016503
# iday      -0.007034 -0.007323  0.014218  1.000000 -0.006115  0.025349
# extended  -0.060690 -0.060776  0.013265 -0.006115  1.000000 -0.061500
# ...             ...       ...       ...       ...       ...       ...
# nreleased  0.011545  0.011967 -0.038540 -0.018405  0.001410  0.081667
# INT_LOG   -0.051474 -0.051470 -0.004923  0.012444  0.025125  0.192402
# INT_IDEO  -0.055428 -0.055435 -0.003357  0.010923  0.032794  0.184051
# INT_MISC  -0.198934 -0.199143  0.036082  0.016162  0.033425  0.392506
# INT_ANY   -0.138867 -0.138896  0.004802  0.018530  0.031017  0.300659
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# eventid   -0.056990 -0.310738  -0.007800     0.137889  ...   0.011279
# iyear     -0.056589 -0.310183  -0.007665     0.138179  ...   0.011679
# imonth    -0.028740 -0.015239  -0.012473    -0.043843  ...  -0.037475
# iday       0.007356  0.011399  -0.007279    -0.008039  ...   0.003177
# extended  -0.018588 -0.068848   0.001014     0.024590  ...  -0.033162
# ...             ...       ...        ...          ...  ...        ...
# nreleased  0.144892  0.146179   0.195225    -0.044226  ...   0.006771
# INT_LOG    0.108328  0.106774   0.008812    -0.001668  ...   0.038066
# INT_IDEO   0.109837  0.102841   0.008793    -0.003294  ...   0.034730
# INT_MISC   0.215833  0.251662   0.002943    -0.063576  ...  -0.014744
# INT_ANY    0.223573  0.206343   0.010564    -0.044618  ...   0.025086
#
#            ransomamtus  ransompaid  ransompaidus  hostkidoutcome  nreleased  \
# eventid            NaN   -0.126160           NaN        0.082080   0.011545
# iyear              NaN   -0.128501           NaN        0.081908   0.011967
# imonth             NaN    0.202327           NaN        0.014741  -0.038540
# iday               NaN    0.014114           NaN        0.059868  -0.018405
# extended           NaN   -0.135970           NaN       -0.083684   0.001410
# ...                ...         ...           ...             ...        ...
# nreleased          NaN   -0.038965           NaN       -0.162178   1.000000
# INT_LOG            NaN   -0.050077           NaN       -0.093060   0.013475
# INT_IDEO           NaN   -0.045284           NaN       -0.104763   0.011796
# INT_MISC           NaN    0.021537           NaN       -0.000892   0.024506
# INT_ANY            NaN    0.004150           NaN       -0.092870   0.037916
#
#             INT_LOG  INT_IDEO  INT_MISC   INT_ANY
# eventid   -0.051474 -0.055428 -0.198934 -0.138867
# iyear     -0.051470 -0.055435 -0.199143 -0.138896
# imonth    -0.004923 -0.003357  0.036082  0.004802
# iday       0.012444  0.010923  0.016162  0.018530
# extended   0.025125  0.032794  0.033425  0.031017
# ...             ...       ...       ...       ...
# nreleased  0.013475  0.011796  0.024506  0.037916
# INT_LOG    1.000000  0.994879  0.114180  0.814730
# INT_IDEO   0.994879  1.000000  0.139023  0.817017
# INT_MISC   0.114180  0.139023  1.000000  0.380077
# INT_ANY    0.814730  0.817017  0.380077  1.000000
#
# [79 rows x 79 columns]

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
data.nunique()
# Out:
# eventid       18870
# iyear            15
# imonth           13
# iday             32
# approxdate       19
#               ...
# INT_LOG           3
# INT_IDEO          3
# INT_MISC          3
# INT_ANY           3
# related         154
# Length: 135, dtype: int64

# %%
data.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %%
#check nulls
data.isnull()
# Out:
#        eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0        False  False   False  False        True     False        True
# 1        False  False   False  False        True     False        True
# 2        False  False   False  False        True     False        True
# 3        False  False   False  False        True     False        True
# 4        False  False   False  False        True     False        True
# ...        ...    ...     ...    ...         ...       ...         ...
# 18865    False  False   False  False        True     False        True
# 18866    False  False   False  False        True     False        True
# 18867    False  False   False  False        True     False        True
# 18868    False  False   False  False        True     False        True
# 18869    False  False   False  False        True     False        True
#
#        country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# 0        False        False   False  ...      True    True    True    True
# 1        False        False   False  ...      True    True    True    True
# 2        False        False   False  ...      True    True    True    True
# 3        False        False   False  ...      True    True    True    True
# 4        False        False   False  ...      True    True    True    True
# ...        ...          ...     ...  ...       ...     ...     ...     ...
# 18865    False        False   False  ...      True    True    True    True
# 18866    False        False   False  ...      True    True    True    True
# 18867    False        False   False  ...      True    True    True    True
# 18868    False        False   False  ...      True    True    True    True
# 18869    False        False   False  ...      True    True    True    True
#
#        dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# 0         False    False     False     False    False     True
# 1         False    False     False     False    False     True
# 2         False    False     False     False    False     True
# 3         False    False     False     False    False     True
# 4         False    False     False     False    False     True
# ...         ...      ...       ...       ...      ...      ...
# 18865     False    False     False     False    False     True
# 18866     False    False     False     False    False     True
# 18867     False    False     False     False    False     True
# 18868     False    False     False     False    False     True
# 18869      True     True      True      True     True     True
#
# [18870 rows x 135 columns]

# %%
data.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    18849
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       18143
# Length: 135, dtype: int64

# %%
data['nkill']=data['nkill'].fillna(0)
data['nwound']=data['nwound'].fillna(0)

# %%
data['Casualities'] = data['nkill'] + data['nwound']

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate     18849
#                ...
# INT_IDEO           1
# INT_MISC           1
# INT_ANY            1
# related        18143
# Casualities        0
# Length: 136, dtype: int64

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... scite1 scite2 scite3  dbsource  INT_LOG  \
# 0  Dominican Republic       2  ...    NaN    NaN    NaN      PGIS      0.0
# 1              Mexico       1  ...    NaN    NaN    NaN      PGIS      0.0
# 2         Philippines       5  ...    NaN    NaN    NaN      PGIS     -9.0
# 3              Greece       8  ...    NaN    NaN    NaN      PGIS     -9.0
# 4               Japan       4  ...    NaN    NaN    NaN      PGIS     -9.0
#
#    INT_IDEO  INT_MISC INT_ANY related  Casualities
# 0       0.0       0.0     0.0     NaN          1.0
# 1       1.0       1.0     1.0     NaN          0.0
# 2      -9.0       1.0     1.0     NaN          1.0
# 3      -9.0       1.0     1.0     NaN          0.0
# 4      -9.0       1.0     1.0     NaN          0.0
#
# [5 rows x 136 columns]

# %%
year = data['iyear'].unique()
years_count = data['iyear'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (15,10))
sns.barplot(x = year, y = years_count, palette = 'tab10')
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year')
plt.title('Attacks In Years',fontsize=22)
plt.show()

# %% [markdown]
# **Here, The graph shows the number of Attacks in each year from 1970 to 1992 and here we observed that the number of global terrorism attacks are continuously increasing from 1988 . The Graph shows 1991 is the most unlucky year because the most number of attacks took place in the year 1991.**

# %%
Data = data[['iyear','nkill']].groupby(['iyear']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
Data.plot(kind='bar',alpha=0.7,ax=ax4, color="purple")
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack")
plt.ylabel("Number of killed peope")
plt.xlabel('Year')
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %% [markdown]
# **The graph shows the number of people killed from the year 1970 to 1992. As number of attacks increases, the people killed in attacks is also increases. The number of killed people is atmost in 1984**

# %%
data['gname'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='salmon',figsize=(20,10))
plt.title("Top 10 terrorist group attack")
plt.xlabel("terrorist group name")
plt.ylabel("Attack number")
plt.show()

# %%
data['attacktype1_txt'].value_counts().plot(kind='bar',figsize=(20,10),color='aqua')
plt.xticks(rotation = 50)
plt.xlabel("Attack Type")
plt.ylabel("Number of attack")
plt.title("Name of attacktype")
plt.show()

# %% [markdown]
# **The Graph shows that which type of attack is mostly used. Here we observed that the Bombing/Explosion type attack were used most of time.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already loaded your data into the 'data' DataFrame

# Calculate value counts and their order
value_counts = data['targtype1_txt'].value_counts()
value_order = value_counts.index

# Create the countplot
plt.subplots(figsize=(20, 10))
sns.countplot(
    x="targtype1_txt",
    data=data,
    order=value_order,
    palette="gist_heat",
    edgecolor=sns.color_palette("Set2")
)
plt.xticks(rotation=90)
plt.xlabel("Attacktype")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Here we observed that Private Citizen and Property Attacks were more as compared to other attack types.**

# %%
kill = data.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 25667

# %%
df = data.pivot_table(columns='attacktype1_txt', values='nkill', aggfunc='sum')
df
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# nkill                  13718.0         3941.0             5348.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# nkill                                     591.0      186.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# nkill                                          240.0
#
# attacktype1_txt  Hostage Taking (Kidnapping)  Unarmed Assault  Unknown
# nkill                                  389.0             19.0   1235.0

# %%
df1 = data.pivot_table(columns='country', values='nkill', aggfunc='sum')
df1
# Out:
# country   4    5    6    7      8      11   14    15   17   18   ...   362  \
# nkill    53.0  0.0  0.0  0.0  134.0  329.0  6.0  12.0  0.0  0.0  ...  68.0
#
# country  377    403  406   428  499  532     603  604   605
# nkill    3.0  217.0  0.0  81.0  1.0  0.0  2058.0  1.0  15.0
#
# [1 rows x 129 columns]

# %%
#top 10 countries with most number of attacks
attack = data.country.value_counts()[:10]
attack
# Out:
# 61     2547
# 603    2087
# 217    1711
# 185    1374
# 98     1226
# 83     1194
# 45     1051
# 69      781
# 159     757
# 209     593
# Name: country, dtype: int64

# %%
#top 10 terrorist groups with most number of attacks
data.gname.value_counts()[1:11]
# Out:
# Irish Republican Army (IRA)                         1332
# Farabundo Marti National Liberation Front (FMLN)     778
# Basque Fatherland and Freedom (ETA)                  768
# Shining Path (SL)                                    515
# Palestinians                                         416
# Revolutionary Armed Forces of Colombia (FARC)        310
# M-19 (Movement of April 19)                          259
# Protestant extremists                                220
# Red Brigades                                         209
# Sandinista National Liberation Front (FSLN)          197
# Name: gname, dtype: int64

# %% [markdown]
# # Summary
#
# Highest number of attacks took place in 2014.
#
# Leading to highest death rate in that year(2014).
#
# Taliban has done the hightest number of attacks out of all terrorist groups.
#
# The highest number of attacks took place in Iraq.
#
# The most frequent attack types were bombing/explosion.
#
# These attacks affected provate citizens and propertiest the most
